# %% [markdown]
# ## Base de dados Rain in Australia
#
# A base de dados contém cerca de 10 anos de observações meteorológicas diárias de vários locais da Austrália.
#
# * Classe/rótulo: RainTomorrow (No/Yes)
# * Total: 142.193 registros
# * Classe negativa/No: 110.316 registros
# * Classe positiva/Yes: 31.877 registros

# %% [markdown]
# ### Objetivo: Prever a chuva do dia seguinte treinando modelos de classificação na variável alvo RainTomorrow (Chove_Amanha).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Carregar base de dados

# %%
# dataset de teste
test = pd.read_csv('input/test.csv')
test.head()
# Out:
#    Id        Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   1  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1   5  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 2   7  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 3  19  2008-12-19   Albury     11.2     22.5      10.6          NaN       NaN
# 4  25  2008-12-25   Albury     12.6     32.4       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  ... Humidity9am Humidity3pm  Pressure9am  \
# 0           W           44.0  ...        71.0        22.0       1007.7
# 1           W           41.0  ...        82.0        33.0       1010.8
# 2           W           50.0  ...        49.0        19.0       1009.6
# 3         SSE           43.0  ...        47.0        32.0       1009.4
# 4           W           43.0  ...        49.0        17.0       1012.9
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# 0       1007.1       8.0       NaN     16.9     21.8         No            No
# 1       1006.0       7.0       8.0     17.8     29.7         No            No
# 2       1008.2       1.0       NaN     18.1     24.6         No            No
# 3       1009.7       NaN       2.0     15.5     21.0        Yes            No
# 4       1010.1       NaN       NaN     21.5     31.2         No            No
#
# [5 rows x 24 columns]

# %%
# dataset de treino
train = pd.read_csv('input/train.csv')
train.head()
# Out:
#    Id        Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   2  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 1   3  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 2   4  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 3   6  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 4   8  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed  ... Humidity9am Humidity3pm  Pressure9am  \
# 0         WNW           44.0  ...        44.0        25.0       1010.6
# 1         WSW           46.0  ...        38.0        30.0       1007.6
# 2          NE           24.0  ...        45.0        16.0       1017.6
# 3         WNW           56.0  ...        55.0        23.0       1009.2
# 4           W           35.0  ...        48.0        19.0       1013.4
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# 0       1007.8       NaN       NaN     17.2     24.3         No            No
# 1       1008.7       NaN       2.0     21.0     23.2         No            No
# 2       1012.8       NaN       NaN     18.1     26.5         No            No
# 3       1005.4       NaN       NaN     20.6     28.9         No            No
# 4       1010.1       NaN       NaN     16.3     25.5         No            No
#
# [5 rows x 24 columns]

# %%
# shape test e treino
print("Shape teste:{} e treino:{}".format(test.shape,train.shape))
# Out:
# Shape teste:(28439, 24) e treino(113754, 24)

# %% [markdown]
# ### Junção das bases de treino e teste

# %%
data = pd.concat([test,train],sort=True)
data.head()
# Out:
#    Cloud3pm  Cloud9am        Date  Evaporation  Humidity3pm  Humidity9am  Id  \
# 0       NaN       8.0  2008-12-01          NaN         22.0         71.0   1
# 1       8.0       7.0  2008-12-05          NaN         33.0         82.0   5
# 2       NaN       1.0  2008-12-07          NaN         19.0         49.0   7
# 3       2.0       NaN  2008-12-19          NaN         32.0         47.0  19
# 4       NaN       NaN  2008-12-25          NaN         17.0         49.0  25
#
#   Location  MaxTemp  MinTemp  ...  Rainfall  Sunshine Temp3pm Temp9am  \
# 0   Albury     22.9     13.4  ...       0.6       NaN    21.8    16.9
# 1   Albury     32.3     17.5  ...       1.0       NaN    29.7    17.8
# 2   Albury     25.0     14.3  ...       0.0       NaN    24.6    18.1
# 3   Albury     22.5     11.2  ...      10.6       NaN    21.0    15.5
# 4   Albury     32.4     12.6  ...       0.0       NaN    31.2    21.5
#
#    WindDir3pm  WindDir9am  WindGustDir  WindGustSpeed WindSpeed3pm  \
# 0         WNW           W            W           44.0         24.0
# 1          NW         ENE            W           41.0         20.0
# 2           W          SW            W           50.0         24.0
# 3          SW         WSW          SSE           43.0         17.0
# 4           W           E            W           43.0         19.0
#
#   WindSpeed9am
# 0         20.0
# 1          7.0
# 2         20.0
# 3         24.0
# 4          4.0
#
# [5 rows x 24 columns]

# %%
# definindo a coluna id como index
data.set_index('Id', inplace=True)
data.sort_index(inplace=True)
data.head()
# Out:
#     Cloud3pm  Cloud9am        Date  Evaporation  Humidity3pm  Humidity9am  \
# Id
# 1        NaN       8.0  2008-12-01          NaN         22.0         71.0
# 2        NaN       NaN  2008-12-02          NaN         25.0         44.0
# 3        2.0       NaN  2008-12-03          NaN         30.0         38.0
# 4        NaN       NaN  2008-12-04          NaN         16.0         45.0
# 5        8.0       7.0  2008-12-05          NaN         33.0         82.0
#
#    Location  MaxTemp  MinTemp  Pressure3pm  ...  Rainfall Sunshine Temp3pm  \
# Id                                          ...
# 1    Albury     22.9     13.4       1007.1  ...       0.6      NaN    21.8
# 2    Albury     25.1      7.4       1007.8  ...       0.0      NaN    24.3
# 3    Albury     25.7     12.9       1008.7  ...       0.0      NaN    23.2
# 4    Albury     28.0      9.2       1012.8  ...       0.0      NaN    26.5
# 5    Albury     32.3     17.5       1006.0  ...       1.0      NaN    29.7
#
#     Temp9am  WindDir3pm  WindDir9am  WindGustDir WindGustSpeed WindSpeed3pm  \
# Id
# 1      16.9         WNW           W            W          44.0         24.0
# 2      17.2         WSW         NNW          WNW          44.0         22.0
# 3      21.0         WSW           W          WSW          46.0         26.0
# 4      18.1           E          SE           NE          24.0          9.0
# 5      17.8          NW         ENE            W          41.0         20.0
#
#    WindSpeed9am
# Id
# 1          20.0
# 2           4.0
# 3          19.0
# 4          11.0
# 5           7.0
#
# [5 rows x 23 columns]

# %%
# shape 
data.shape
# Out:
# (142193, 23)

# %%
# Renomear as colunas

data.columns = [
    'Nuvem_3_Tarde','Nuvem_9_Manha','Data','Evaporacao','Umidade_3_Tarde','Umidade_9_Manha','Localizacao','Temperatura_Maxima',
    'Temperatura_Minima','Pressao_3_Tarde','Pressao_9_Manha','Chove_Hoje','Chove_Amanha','Pluviosidade','Brilho_Do_Sol',
    'Temperatura_3_Tarde','Temperatura_9_Manha','Direcao_Vento_3_Tarde','Direcao_Vento_9_Manha','Direcao_Rajada_Vento',
    'Velocidade_Rajada_Vento', 'Velocidade_Vento_3_Tarde', 'Velocidade_Vento_9_Manha'
]
data.head()
# Out:
#     Nuvem_3_Tarde  Nuvem_9_Manha        Data  Evaporacao  Umidade_3_Tarde  \
# Id
# 1             NaN            8.0  2008-12-01         NaN             22.0
# 2             NaN            NaN  2008-12-02         NaN             25.0
# 3             2.0            NaN  2008-12-03         NaN             30.0
# 4             NaN            NaN  2008-12-04         NaN             16.0
# 5             8.0            7.0  2008-12-05         NaN             33.0
#
#     Umidade_9_Manha Localizacao  Temperatura_Maxima  Temperatura_Minima  \
# Id
# 1              71.0      Albury                22.9                13.4
# 2              44.0      Albury                25.1                 7.4
# 3              38.0      Albury                25.7                12.9
# 4              45.0      Albury                28.0                 9.2
# 5              82.0      Albury                32.3                17.5
#
#     Pressao_3_Tarde  ...  Pluviosidade Brilho_Do_Sol Temperatura_3_Tarde  \
# Id                   ...
# 1            1007.1  ...           0.6           NaN                21.8
# 2            1007.8  ...           0.0           NaN                24.3
# 3            1008.7  ...           0.0           NaN                23.2
# 4            1012.8  ...           0.0           NaN                26.5
# 5            1006.0  ...           1.0           NaN                29.7
#
#     Temperatura_9_Manha  Direcao_Vento_3_Tarde  Direcao_Vento_9_Manha  \
# Id
# 1                  16.9                    WNW                      W
# 2                  17.2                    WSW                    NNW
# 3                  21.0                    WSW                      W
# 4                  18.1                      E                     SE
# 5                  17.8                     NW                    ENE
#
#     Direcao_Rajada_Vento Velocidade_Rajada_Vento Velocidade_Vento_3_Tarde  \
# Id
# 1                      W                    44.0                     24.0
# 2                    WNW                    44.0                     22.0
# 3                    WSW                    46.0                     26.0
# 4                     NE                    24.0                      9.0
# 5                      W                    41.0                     20.0
#
#    Velocidade_Vento_9_Manha
# Id
# 1                      20.0
# 2                       4.0
# 3                      19.0
# 4                      11.0
# 5                       7.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Endendendo o dataset

# %%
data.dtypes
# Out:
# Nuvem_3_Tarde               float64
# Nuvem_9_Manha               float64
# Data                         object
# Evaporacao                  float64
# Umidade_3_Tarde             float64
# Umidade_9_Manha             float64
# Localizacao                  object
# Temperatura_Maxima          float64
# Temperatura_Minima          float64
# Pressao_3_Tarde             float64
# Pressao_9_Manha             float64
# Chove_Hoje                   object
# Chove_Amanha                 object
# Pluviosidade                float64
# Brilho_Do_Sol               float64
# Temperatura_3_Tarde         float64
# Temperatura_9_Manha         float64
# Direcao_Vento_3_Tarde        object
# Direcao_Vento_9_Manha        object
# Direcao_Rajada_Vento         object
# Velocidade_Rajada_Vento     float64
# Velocidade_Vento_3_Tarde    float64
# Velocidade_Vento_9_Manha    float64
# dtype: object

# %%
data.describe()
# variáveis continuas
# Out:
#        Nuvem_3_Tarde  Nuvem_9_Manha    Evaporacao  Umidade_3_Tarde  \
# count   85099.000000   88536.000000  81350.000000    138583.000000
# mean        4.503167       4.437189      5.469824        51.482606
# std         2.720633       2.887016      4.188537        20.797772
# min         0.000000       0.000000      0.000000         0.000000
# 25%         2.000000       1.000000      2.600000        37.000000
# 50%         5.000000       5.000000      4.800000        52.000000
# 75%         7.000000       7.000000      7.400000        66.000000
# max         9.000000       9.000000    145.000000       100.000000
#
#        Umidade_9_Manha  Temperatura_Maxima  Temperatura_Minima  \
# count    140419.000000       141871.000000       141556.000000
# mean         68.843810           23.226784           12.186400
# std          19.051293            7.117618            6.403283
# min           0.000000           -4.800000           -8.500000
# 25%          57.000000           17.900000            7.600000
# 50%          70.000000           22.600000           12.000000
# 75%          83.000000           28.200000           16.800000
# max         100.000000           48.100000           33.900000
#
#        Pressao_3_Tarde  Pressao_9_Manha   Pluviosidade  Brilho_Do_Sol  \
# count    128212.000000    128179.000000  140787.000000   74377.000000
# mean       1015.258204      1017.653758       2.349974       7.624853
# std           7.036677         7.105476       8.465173       3.781525
# min         977.100000       980.500000       0.000000       0.000000
# 25%        1010.400000      1012.900000       0.000000       4.900000
# 50%        1015.200000      1017.600000       0.000000       8.500000
# 75%        1020.000000      1022.400000       0.800000      10.600000
# max        1039.600000      1041.000000     371.000000      14.500000
#
#        Temperatura_3_Tarde  Temperatura_9_Manha  Velocidade_Rajada_Vento  \
# count        139467.000000        141289.000000            132923.000000
# mean             21.687235            16.987509                39.984292
# std               6.937594             6.492838                13.588801
# min              -5.400000            -7.200000                 6.000000
# 25%              16.600000            12.300000                31.000000
# 50%              21.100000            16.700000                39.000000
# 75%              26.400000            21.600000                48.000000
# max              46.700000            40.200000               135.000000
#
#        Velocidade_Vento_3_Tarde  Velocidade_Vento_9_Manha
# count             139563.000000             140845.000000
# mean                  18.637576                 14.001988
# std                    8.803345                  8.893337
# min                    0.000000                  0.000000
# 25%                   13.000000                  7.000000
# 50%                   19.000000                 13.000000
# 75%                   24.000000                 19.000000
# max                   87.000000                130.000000

# %%
data.describe(include=['O'])
# variáveis categóricas
# Out:
#               Data Localizacao Chove_Hoje Chove_Amanha Direcao_Vento_3_Tarde  \
# count       142193      142193     140787       142193                138415
# unique        3436          49          2            2                    16
# top     2013-12-01    Canberra         No           No                    SE
# freq            49        3418     109332       110316                 10663
#
#        Direcao_Vento_9_Manha Direcao_Rajada_Vento
# count                 132180               132863
# unique                    16                   16
# top                        N                    W
# freq                   11393                 9780

# %% [markdown]
# ### Preparação dos dados
